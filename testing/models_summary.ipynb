# %%
# Import Modules & Add Direct Path to Previous Dir

# %%
import sys
from networks import CNN
sys.path.insert(0, '../')

# %%
# Set Input Shape for Image

# %%
input_shape = (48, 48, 1)
num_classes = 7

# %%
# Create and Compile the Model

# %%
model = CNN(input_shape, num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary() # view the model summary
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# image_array (Conv2D)         (None, 48, 48, 16)        800
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 48, 48, 16)        64
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 48, 48, 16)        12560
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 48, 48, 16)        64
# _________________________________________________________________
# activation_25 (Activation)   (None, 48, 48, 16)        0
# _________________________________________________________________
# average_pooling2d_13 (Averag (None, 24, 24, 16)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 24, 24, 16)        0
# ...

# %%
from networks import XCEPTION

# %%
# Set Input Shape for Image

# %%
input_shape_2 = (64, 64, 1)
num_classes_2 = 7

# %%
# Create and Compile the Model

# %%
model = XCEPTION(input_shape_2, num_classes_2)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 62, 62, 8)    72          input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 62, 62, 8)    32          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 62, 62, 8)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# ...
